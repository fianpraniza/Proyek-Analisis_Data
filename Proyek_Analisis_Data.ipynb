# %% [markdown]
# # Proyek Analisis Data: [E-commerce Public Dataset]
# - **Nama:** [Muhammad Arfian Praniza]
# - **Email:** [fianpraniza@gmail.com]
# - **ID Dicoding:** [fianpraniza]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Produk apa saja yang sering dibeli?
# - Kapan waktu puncak penjualan terjadi?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %% [markdown]
# - memuat data csv yang tersedia dalam dataset kedalam DataFrame(df)
# - tampilkan data frame

# %%
df_customers = pd.read_csv('dataset/customers_dataset.csv')
df_geolocation = pd.read_csv('dataset/geolocation_dataset.csv')
df_order_item = pd.read_csv('dataset/order_items_dataset.csv')
df_order_payments = pd.read_csv('dataset/order_payments_dataset.csv')
df_order_reviews = pd.read_csv('dataset/order_reviews_dataset.csv')
df_orders = pd.read_csv('dataset/orders_dataset.csv')
df_product_category = pd.read_csv('dataset/product_category_name_translation.csv')
df_products = pd.read_csv('dataset/products_dataset.csv')
df_sellers = pd.read_csv('dataset/sellers_dataset.csv')

# %%
df_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
df_geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
df_order_item.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
df_order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
df_order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
df_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
df_product_category.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
df_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df_sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# proses penilaian data, apakah terdapat kesalahan tipe data, duplikasi data, missing values(NaN/null) pada tiap dataset

# %% [markdown]
# 1. Assessing Data Customer

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
print('Data yang terduplikat:', df_customers.duplicated().sum())
# Out:
# Data yang terduplikat: 0

# %%
#pengecekan data customers apakah terdapat missing values
df_customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# Pada DataFrame customers bersih, tidak terdapat data yang terduplikat dan missing values

# %% [markdown]
# 2. Assessing Data Geografis

# %%
df_geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
print('Data yang terduplikat:', df_geolocation.duplicated().sum())
# Out:
# Data yang terduplikat: 261831

# %%
#pengecekan data geolocation apakah terdapat missing values
df_geolocation.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %% [markdown]
# Pada DataFrame geolocation terdapat data yang terduplikat

# %% [markdown]
# 3. Assessing Data Orders Items

# %%
df_order_item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
print('Data yang terduplikat:', df_order_item.duplicated().sum())
# Out:
# Data yang terduplikat: 0

# %%
df_order_item.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# Pada DataFrame Order Items terdapat kesalahan tipe data pada kolom shipping_limit_date yang seharusnya memiliki tipe data datetime

# %% [markdown]
# 4. Assessing Data Order Payments

# %%
df_order_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
print('Data yang terduplikat:', df_order_payments.duplicated().sum())
# Out:
# Data yang terduplikat: 0

# %%
df_order_payments.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %% [markdown]
# Pada DataFrame order payments bersih

# %% [markdown]
# 5. Assessing Data Order Reviews

# %%
df_order_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
print('Data yang terduplikat:', df_order_reviews.duplicated().sum())
# Out:
# Data yang terduplikat: 0

# %%
df_order_reviews.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# Pada DataFrame terdapat missing values dan tipe data yang salah pada kolom review_creation_date dan review_answer_timestamp yang seharusnya memiliki tipe data datetime

# %% [markdown]
# 6. Assessing Data Orders

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
print('Data yang terduplikat:', df_orders.duplicated().sum())
# Out:
# Data yang terduplikat: 0

# %%
df_orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# Pada DataFrame data orders terdapat missing values, tipe data yang salah pada kolom order_purchase_timestamp, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date seharusnya memiliki tipe data datetime

# %% [markdown]
# 7. Assessing Data Product Category

# %%
df_product_category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
print('Data yang terduplikat:', df_product_category.duplicated().sum())
# Out:
# Data yang terduplikat: 0

# %%
df_product_category.isnull().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %% [markdown]
# Pada DataFrame product category bersih

# %% [markdown]
# 8. Assessing Data Products

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
print('Data yang terduplikat:', df_products.duplicated().sum())
# Out:
# Data yang terduplikat: 0

# %%
df_products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# Pada DataFrame products hanya memiliki missing values

# %% [markdown]
# 9. Assessing Data Sellers

# %%
df_sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
print('Data yang terduplikat:', df_sellers.duplicated().sum())
# Out:
# Data yang terduplikat: 0

# %%
df_sellers.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %% [markdown]
# Pada DataFrame sellers bersih

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# memberikan perlakuan berdasarkan penilaian data (Assessing Data) yang telah dilakukan

# %% [markdown]
# 1. Mengubah Tipe data object menjadi datetime, pada kolom:
# - shipping_limit_date
# - review_creation_date
# - review_answer_timestamp
# - order_purchase_timestamp
# - order_approved_at
# - order_delivered_carrier_date
# - order_delivered_customer_date
# - order_estimated_delivery_date
#
# sesuai dengan asal DataFrame masing-masing kolom

# %%
datetime = ['shipping_limit_date']

for column in datetime:
    df_order_item[column] = pd.to_datetime(df_order_item[column])

# %%
datetime = ['review_creation_date', 'review_answer_timestamp']

for column in datetime:
    df_order_reviews[column] = pd.to_datetime(df_order_reviews[column])

# %%
datetime = ['order_purchase_timestamp', 'order_approved_at','order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']

for column in datetime:
    df_orders[column] = pd.to_datetime(df_orders[column])

# %% [markdown]
# Pengecekan ulang apakah tipe data sudah berubah

# %%
df_order_item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  datetime64[ns]
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(3)
# memory usage: 6.0+ MB

# %%
df_order_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  datetime64[ns]
#  6   review_answer_timestamp  99224 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 5.3+ MB

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %% [markdown]
# tipe data telah selesai diubah dan tidak terdapat kesalahan pada tipe data lainnya

# %% [markdown]
# 2. Pengisian nilai pada Missing values yang terdapat pada DataFrame:
#
#     2.1 order_reviews
#
#     2.2 orders
#
#     2.3 products

# %% [markdown]
# 2.1 order_reviews:
# - review_comment_title       87656
# - review_comment_message     58247

# %%
#menampilkan missing values yang terdapat pada kolom review_comment_title
df_order_reviews[df_order_reviews.review_comment_title.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# ...

# %% [markdown]
# dapat dilihat kolom review_comment_title, terdapat missing values pada indeks 0,1,2,3,4, dst

# %%
#menampilkan missing values yang terdapat pada kolom review_comment_message
df_order_reviews[df_order_reviews.review_comment_message.isna()]
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 5      15197aa66ff4d0650b5434f1b46cda19  b18dcdf73be66366873cd26c5724d1dc
# 6      07f9bee5d1b850860defd761afa7ff16  e48aa0d2dcec3a2e87348811bcfdf22b
# ...                                 ...                               ...
# 99217  c6b270c61f67c9f7cb07d84ea8aeaf8b  48f7ee67313eda32bfcf5b9c1dd9522d
# 99218  af2dc0519de6e0720ef0c74292fb4114  d699c734a0b1c8111f2272a3f36d398c
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
#
#        review_score review_comment_title review_comment_message  \
# ...

# %% [markdown]
# dapat dilihat kolom review_comment_message, terdapat missing values pada indeks 0,1,2,5,6, dst

# %%
#menampilkan jumlah kemunculan/frekuensi judul komen dari terbanyak hingga terdikit
df_order_reviews.review_comment_title.value_counts()
# Out:
# review_comment_title
# Recomendo                    423
# recomendo                    345
# Bom                          293
# super recomendo              270
# Excelente                    248
#                             ...
# Luminaria sobrepor led 18      1
# Não recebi.                    1
# produto com lacre violado      1
# Atraso Entrega                 1
# Foto enganosa                  1
# Name: count, Length: 4527, dtype: int64

# %%
#menampilkan jumlah isi pesan dari terbanyak hingga terdikit
df_order_reviews.review_comment_message.value_counts()
# Out:
# review_comment_message
# Muito bom                                                                                                                                                                                              230
# Bom                                                                                                                                                                                                    189
# muito bom                                                                                                                                                                                              122
# bom                                                                                                                                                                                                    107
# ...

# %%
#mengisi missing values
df_order_reviews.fillna(value='NO REVIEW.', inplace=True)

# %%
#pengecekan ulang apakah missing values telah berubah menjadi 'NO REVIEW.'
df_order_reviews.review_comment_title.value_counts()
# Out:
# review_comment_title
# NO REVIEW.                   87656
# Recomendo                      423
# recomendo                      345
# Bom                            293
# super recomendo                270
#                              ...
# Luminaria sobrepor led 18        1
# Não recebi.                      1
# produto com lacre violado        1
# Atraso Entrega                   1
# Foto enganosa                    1
# Name: count, Length: 4528, dtype: int64

# %%
df_order_reviews.review_comment_message.value_counts()
# Out:
# review_comment_message
# NO REVIEW.                                                                                                                                                                                             58247
# Muito bom                                                                                                                                                                                                230
# Bom                                                                                                                                                                                                      189
# muito bom                                                                                                                                                                                                122
# ...

# %% [markdown]
# Pengisian missing values pada DataFrame order reviews telah selesai.

# %% [markdown]
# 2.2 orders:
# - order_approved_at                 160
# - order_delivered_carrier_date     1783
# - order_delivered_customer_date    2965

# %%
#melihat missing values dimulai pada indeks keberapa pada kolom order_approved_at
df_orders[df_orders.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
df_orders[df_orders.order_delivered_carrier_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 266    8e24261a7e58791d10cb1bf9da94df5c  64a254d30eed42cd0e6c36dddb88adf0
# 324    d3c8851a6651eeff2f73b0e011ac45d0  957f8e082185574de25992dc659ebbc0
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
df_orders[df_orders.order_delivered_customer_date.isna()]
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   97658 non-null  datetime64[ns]
#  6   order_delivered_customer_date  96476 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](5), object(3)
# memory usage: 6.1+ MB

# %%
#menghapus missing values pada DataFrame orders dengan tipe data date, karena terlalu banyak dan tidak ingin menebak tanggal yang tidak terekam
df_orders.dropna(subset=['order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date'], inplace=True)

# %% [markdown]
# Penghapusan missing values pada DataFrame orders telah selesai.

# %% [markdown]
# 2.3 products:
# - product_category_name         610
# - product_name_lenght           610
# - product_description_lenght    610
# - product_photos_qty            610
# - product_weight_g                2
# - product_length_cm               2
# - product_height_cm               2
# - product_width_cm                2

# %%
df_products[df_products.product_category_name.isna()]
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
df_products.product_category_name.value_counts()
# Out:
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 73, dtype: int64

# %%
#menghapus missing values pada DataFrame products, karena missing values relatif kecil dan tidak akan memengaruhi analisis secara signifikan
df_products.dropna(subset=['product_category_name','product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm'], inplace=True)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Data Customers

# %%
df_customers.describe(include='all')
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
df_customers.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 83731  8d0b32e63e627ec62fd798ce668efc7a  4dc1ee083d58f95951fe4c9dbb489449
# 6974   edbe69fae8335bc4aab71431a8cfe6d3  902136370dba306ea83aee9f6a68f649
# 42604  98a8003e51fa117ecb46c24ef8f419df  9d3abddad51efa4368aa7d0bd0dce9e2
# 84121  3539e22bd0a0cf0a601c207ec0af55be  0cd6b4fa28f514d6dc33fe708333830e
# 9605   9e34ec8b56a283cbd0570abf24ea2e5f  257296c7675330e1bf543f35d484034d
#
#        customer_zip_code_prefix   customer_city customer_state
# 83731                     21061  rio de janeiro             RJ
# 6974                      28893  rio das ostras             RJ
# 42604                     11060          santos             SP
# 84121                     89600         joacaba             SC
# 9605                      35188       jaguaracu             MG

# %%
df_customers.groupby(by="customer_city").agg({
    "customer_id": "nunique"
}).sort_values(by="customer_id", ascending=False)
# Out:
#                 customer_id
# customer_city
# sao paulo             15540
# rio de janeiro         6882
# belo horizonte         2773
# brasilia               2131
# curitiba               1521
# ...                     ...
# ibiara                    1
# rio espera                1
# rio dos indios            1
# rio dos cedros            1
# lagoao                    1
#
# [4119 rows x 1 columns]

# %%
df_customers.groupby(by="customer_state").agg({
    "customer_id": "nunique"
}).sort_values(by="customer_id", ascending=False)
# Out:
#                 customer_id
# customer_state
# SP                    41746
# RJ                    12852
# MG                    11635
# RS                     5466
# PR                     5045
# SC                     3637
# BA                     3380
# DF                     2140
# ES                     2033
# GO                     2020
# PE                     1652
# CE                     1336
# PA                      975
# MT                      907
# MA                      747
# MS                      715
# PB                      536
# PI                      495
# RN                      485
# AL                      413
# SE                      350
# TO                      280
# RO                      253
# AM                      148
# AC                       81
# AP                       68
# RR                       46

# %% [markdown]
# ### Explore Data Geolocation

# %%
df_geolocation.describe(include='all')
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# count                  1.000163e+06     1.000163e+06     1.000163e+06
# unique                          NaN              NaN              NaN
# top                             NaN              NaN              NaN
# freq                            NaN              NaN              NaN
# mean                   3.657417e+04    -2.117615e+01    -4.639054e+01
# std                    3.054934e+04     5.715866e+00     4.269748e+00
# min                    1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                    1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                    2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                    6.350400e+04    -1.997962e+01    -4.376771e+01
# max                    9.999000e+04     4.506593e+01     1.211054e+02
#
#        geolocation_city geolocation_state
# count           1000163           1000163
# ...

# %%
df_geolocation.groupby('geolocation_zip_code_prefix').size().sort_values(ascending=False)
# Out:
# geolocation_zip_code_prefix
# 24220    1146
# 24230    1102
# 38400     965
# 35500     907
# 11680     879
#          ...
# 20056       1
# 76370       1
# 63012       1
# 76372       1
# 32635       1
# Length: 19015, dtype: int64

# %%
df_geolocation.sample(5)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 16337                          1547       -23.584975       -46.618412
# 462725                        23050       -22.903435       -43.560683
# 683397                        44020       -12.236301       -38.971044
# 880978                        85885       -25.413082       -54.042481
# 232949                         9581       -23.636752       -46.578899
#
#               geolocation_city geolocation_state
# 16337                sao paulo                SP
# 462725          rio de janeiro                RJ
# 683397        feira de santana                BA
# 880978  serranopolis do iguacu                PR
# 232949      sao caetano do sul                SP

# %%
df_geolocation[df_geolocation['geolocation_zip_code_prefix'] == 27213].head()
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 503017                        27213       -22.505695       -44.088639
# 503043                        27213       -22.502997       -44.088251
# 503046                        27213       -22.502997       -44.088251
# 503096                        27213       -22.505695       -44.088639
# 503110                        27213       -22.505196       -44.092189
#
#        geolocation_city geolocation_state
# 503017    volta redonda                RJ
# 503043    volta redonda                RJ
# 503046    volta redonda                RJ
# 503096    volta redonda                RJ
# 503110    volta redonda                RJ

# %% [markdown]
# ### Explore Data Order Item & Sellers (merge)

# %%
df_sellers_item = pd.merge(
    left=df_order_item,
    right=df_sellers,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
df_sellers_item.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#   shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0 2017-09-19 09:45:35   58.90          13.29                   27277
# 1 2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %%
df_sellers_item.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
# guarulhos          50
# ibitinga           49
# santo andre        45
# campinas           41
# maringa            40
# Name: seller_id, dtype: int64

# %%
df_sellers_item.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# Name: seller_id, dtype: int64

# %% [markdown]
# ### Explore Data Orders

# %%
df_orders.sample(5)
# Out:
#                                order_id                       customer_id  \
# 36722  39df1de47e267f7b0ab662c18a428319  767f8e8f093ad7f1f65561d69e39a3b5
# 49280  9c9504bb506aa1635fb6ad19be9bcfa9  5638c42751e237d265ad0c0536256311
# 83048  c642b243037172b9fa789eec22ab713c  b2b7366fa24a7e69a0ad1d4cba6471a9
# 27663  2a2fededb2ec978309f383a4133aa0c5  55de564d672d3c27195edbafd4265870
# 42199  e7f7f03bc8d696fdb62476341f1506f4  d256db1422e2d4737a6e70b39db4e4ef
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 36722    delivered      2017-11-21 19:58:08 2017-11-22 03:20:29
# 49280    delivered      2017-09-06 00:33:14 2017-09-08 07:03:44
# 83048    delivered      2018-01-16 15:21:52 2018-01-16 15:32:25
# 27663    delivered      2018-04-10 20:16:33 2018-04-10 20:29:48
# 42199    delivered      2017-08-24 10:54:50 2017-08-24 11:10:09
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 36722          2017-11-23 22:17:01           2017-12-08 14:57:31
# ...

# %%
df_orders['order_purchase_timestamp'] = pd.to_datetime(df_orders['order_purchase_timestamp'])
df_orders['order_approved_at'] = pd.to_datetime(df_orders['order_approved_at'])


df_orders['processing_time'] = df_orders['order_approved_at'] - df_orders['order_purchase_timestamp']

print(df_orders[['order_id', 'customer_id', 'processing_time']])
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       processing_time
# 0     0 days 00:10:42
# 1     1 days 06:42:50
# ...

# %%
df_orders.sample(5)
# Out:
#                                order_id                       customer_id  \
# 48690  1448f96a9dd749b9b2e69f4b8602912c  23301bca57eda7af3e47546760d9e869
# 74950  afbfc4a5b3161e9e1f89056b0b3ed238  b6868e9d74f44d57435a65e1bfad9be2
# 72962  ca7f087476abd2a0a52b29410dab0939  84004e88cd470bb72eb252f8c9553a66
# 16593  c25acd72d5c2eb2ec89c3c8d7cd7d1f2  1df78c923a7db9f4b3f8bf63edf7adc2
# 40699  8572e18216437c86715d1e5a52321408  e3c038c0f88122fd5b7f566d198acc39
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 48690    delivered      2017-09-06 19:49:30 2017-09-06 20:04:12
# 74950    delivered      2018-02-25 16:47:07 2018-02-27 04:31:06
# 72962    delivered      2018-06-19 23:36:18 2018-06-19 23:59:45
# 16593    delivered      2017-09-08 12:04:02 2017-09-09 05:04:42
# 40699    delivered      2018-08-24 23:28:21 2018-08-24 23:44:19
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 48690          2017-09-08 20:42:18           2017-09-09 12:08:50
# ...

# %%
df_orders.processing_time.describe()
# Out:
# count                        96461
# mean     0 days 10:16:39.837893034
# std      0 days 20:32:08.144063780
# min                0 days 00:00:00
# 25%                0 days 00:12:55
# 50%                0 days 00:20:36
# 75%                0 days 14:31:05
# max               30 days 21:26:37
# Name: processing_time, dtype: object

# %% [markdown]
# ### Explore Data Orders & Customers

# %%
df_orders_customer = pd.merge(
    left=df_customers,
    right=df_orders,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
df_orders_customer.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
df_orders_customer.groupby(by="customer_zip_code_prefix").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_zip_code_prefix
# 22790    136
# 24230    117
# 22793    116
# 24220    115
# 22775    103
# 29101    100
# 35162     92
# 13212     92
# 22631     85
# 38400     85
# Name: order_id, dtype: int64

# %%
df_orders_customer.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_city
# sao paulo                15044
# rio de janeiro            6603
# belo horizonte            2697
# brasilia                  2071
# curitiba                  1489
# campinas                  1406
# porto alegre              1341
# salvador                  1188
# guarulhos                 1143
# sao bernardo do campo      911
# Name: order_id, dtype: int64

# %%
df_orders_customer.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# customer_state
# SP    40489
# RJ    12351
# MG    11352
# RS     5342
# PR     4923
# SC     3547
# BA     3256
# DF     2080
# ES     1995
# GO     1957
# Name: order_id, dtype: int64

# %%
df_orders_customer.groupby(by="order_status").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# order_status
# delivered    96455
# canceled         6
# Name: order_id, dtype: int64

# %%
df_orders_customer.groupby(by="processing_time").order_id.nunique().sort_values(ascending=False).head(10)
# Out:
# processing_time
# 0 days 00:00:00    1244
# 0 days 00:12:10     115
# 0 days 00:11:21     112
# 0 days 00:11:37     111
# 0 days 00:12:02     109
# 0 days 00:12:40     109
# 0 days 00:10:17     108
# 0 days 00:10:55     105
# 0 days 00:11:50     105
# 0 days 00:11:08     104
# Name: order_id, dtype: int64

# %% [markdown]
# ### Explore Data Products & Category

# %%
df_procategory = pd.merge(
    left=df_products,
    right=df_product_category,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
df_procategory.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df_procategory.groupby(by="product_category_name").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name
# cama_mesa_banho           3029
# esporte_lazer             2867
# moveis_decoracao          2657
# beleza_saude              2444
# utilidades_domesticas     2335
# automotivo                1900
# informatica_acessorios    1639
# brinquedos                1411
# relogios_presentes        1329
# telefonia                 1134
# Name: product_id, dtype: int64

# %%
df_procategory.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name_english
# bed_bath_table           3029
# sports_leisure           2867
# furniture_decor          2657
# health_beauty            2444
# housewares               2335
# auto                     1900
# computers_accessories    1639
# toys                     1411
# watches_gifts            1329
# telephony                1134
# Name: product_id, dtype: int64

# %% [markdown]
# ### Explore Data Item Seller & Products

# %%
df_seller_products = pd.merge(
    left=df_products,
    right=df_sellers_item,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
df_seller_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm  \
# 0             225.0               16.0               10.0              14.0
# ...

# %%
df_seller_products.groupby(by="product_category_name").agg({
    "order_id": "nunique",
    "price":  ["min", "max"]
})
# Out:
#                           order_id  price
#                            nunique    min      max
# product_category_name
# agro_industria_e_comercio      182  12.99  2990.00
# alimentos                      450   9.99   274.99
# alimentos_bebidas              227   6.50   699.90
# artes                          202   3.50  6499.00
# artes_e_artesanato              23   9.80   289.49
# ...                            ...    ...      ...
# sinalizacao_e_seguranca        140   4.50   740.00
# tablets_impressao_imagem        79  14.90   889.99
# telefonia                     4199   5.00  2428.00
# telefonia_fixa                 217   6.00  1790.00
# utilidades_domesticas         5884   3.06  6735.00
#
# [73 rows x 3 columns]

# %% [markdown]
# ### Explore Data Payments

# %%
df_order_payments.sample(5)
# Out:
#                                order_id  payment_sequential payment_type  \
# 93552  6512f99fc2b658abc017f8090e3d1bc9                   1  credit_card
# 83047  8ca5bdac5ebe8f2d6fc9171d5ebc906a                   9      voucher
# 51021  a2a6f122566b017e40c435bca2b936f9                   1  credit_card
# 14429  4498a90ce01bc4d0f03ee12f1779ecbf                   1  credit_card
# 42680  b7077d240d1449882a2aa143b428b8b2                   1       boleto
#
#        payment_installments  payment_value
# 93552                     1          46.05
# 83047                     1          25.00
# 51021                     2          27.38
# 14429                     2         116.50
# 42680                     1          65.50

# %%
df_order_payments.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %%
df_payments_review = pd.merge(
    left=df_order_payments,
    right=df_order_reviews,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
df_payments_review.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score review_comment_title  \
# 0           1.0        Não recomendo
# ...

# %%
df_payments_review.groupby(by="payment_type").agg({
    "order_id": "nunique",
    "payment_value":  ["min", "max"]
})
# Out:
#              order_id payment_value
#               nunique           min       max
# payment_type
# boleto          19784         11.62   7274.88
# credit_card     76505          0.01  13664.08
# debit_card       1528         13.38   4445.50
# not_defined         3          0.00      0.00
# voucher          3866          0.00   3184.34

# %%
df_cust = pd.merge(
    left=df_orders_customer,
    right=df_payments_review,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
df_cust.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# ### Explore ALL Data

# %%
allData = pd.merge(
    left=df_cust,
    right=df_seller_products,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
allData.head(5)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %%
allData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118468 entries, 0 to 118467
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   customer_id                    118468 non-null  object
#  1   customer_unique_id             118468 non-null  object
#  2   customer_zip_code_prefix       118468 non-null  int64
#  3   customer_city                  118468 non-null  object
#  4   customer_state                 118468 non-null  object
#  5   order_id                       115488 non-null  object
#  6   order_status                   115488 non-null  object
#  7   order_purchase_timestamp       115488 non-null  datetime64[ns]
#  8   order_approved_at              115488 non-null  datetime64[ns]
#  9   order_delivered_carrier_date   115488 non-null  datetime64[ns]
#  10  order_delivered_customer_date  115488 non-null  datetime64[ns]
# ...

# %%
allData.groupby(by=["customer_city", "product_category_name"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                              price  freight_value
# customer_city       product_category_name
# abadia dos dourados cool_stuff              199.00          20.63
#                     esporte_lazer           120.00          15.59
#                     livros_interesse_geral   39.90          18.38
# abadiania           eletroportateis         949.99          75.53
# abaete              bebes                    65.00          17.70
# ...                                            ...            ...
# ze doca             bebes                    74.80          38.07
#                     esporte_lazer           149.90          38.60
#                     ferramentas_jardim       39.90          26.61
#                     instrumentos_musicais   359.00          49.04
# zortea              informatica_acessorios   69.90          20.98
#
# [24911 rows x 2 columns]

# %%
allData.groupby(by=["customer_state", "product_category_name"]).agg({
    "price": "sum",
    "freight_value": "sum"
})
# Out:
#                                               price  freight_value
# customer_state product_category_name
# AC             artigos_de_natal               69.90          60.95
#                automotivo                    606.97         146.42
#                bebes                         697.84         174.13
#                beleza_saude                 1386.58         268.42
#                brinquedos                    234.79          83.26
# ...                                             ...            ...
# TO             portateis_casa_forno_e_cafe  1999.00          95.44
#                relogios_presentes           4920.89         921.06
#                telefonia                    1268.12         627.34
#                telefonia_fixa               1390.99          53.58
#                utilidades_domesticas         999.97         562.65
#
# [1362 rows x 2 columns]

# %%
allData.groupby(by="customer_state").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# SP                 40489     7434958.12
# RJ                 12351     2694588.60
# MG                 11352     2287820.76
# RS                  5342     1108280.99
# PR                  4923     1034601.30
# BA                  3256      772423.42
# SC                  3547      768559.38
# GO                  1957      496426.61
# DF                  2080      424613.99
# ES                  1995      399201.58
# PE                  1593      361363.59
# CE                  1278      332168.11
# PA                   946      255327.31
# MT                   886      251859.09
# MA                   716      195191.60
# PB                   517      177320.00
# MS                   701      164556.97
# PI                   476      133729.03
# RN                   474      115203.08
# AL                   397      108727.76
# SE                   335       85694.32
# TO                   274       70780.74
# ...

# %%
allData.groupby(by="product_category_name").agg({
    "order_id": "nunique",
    "review_score":  ["min", "max"]
})
# Out:
#                           order_id review_score
#                            nunique          min  max
# product_category_name
# agro_industria_e_comercio      177          1.0  5.0
# alimentos                      441          1.0  5.0
# alimentos_bebidas              221          1.0  5.0
# artes                          195          1.0  5.0
# artes_e_artesanato              23          1.0  5.0
# ...                            ...          ...  ...
# sinalizacao_e_seguranca        138          1.0  5.0
# tablets_impressao_imagem        79          1.0  5.0
# telefonia                     4092          1.0  5.0
# telefonia_fixa                 212          1.0  5.0
# utilidades_domesticas         5743          1.0  5.0
#
# [73 rows x 3 columns]

# %%
allData.to_csv('allData.csv', index=False)

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Produk apa saja yang sering dibeli?

# %%
df_total_penjualan = allData.groupby("product_category_name")["product_id"].count().reset_index()
df_total_penjualan = df_total_penjualan.rename(columns={"product_category_name": "Products Name"})
df_total_penjualan = df_total_penjualan.rename(columns={"product_id": "Products ID"})
df_total_penjualan = df_total_penjualan.sort_values(by="Products ID", ascending=False)
df_total_penjualan = df_total_penjualan.head(10)

df_total_penjualan.head()
# Out:
#              Products Name  Products ID
# 13         cama_mesa_banho        11813
# 11            beleza_saude         9818
# 32           esporte_lazer         8789
# 54        moveis_decoracao         8639
# 44  informatica_acessorios         7962

# %%
plt.figure(figsize=(10, 6))
plt.bar(df_total_penjualan['Products Name'], df_total_penjualan['Products ID'], color='skyblue')
plt.xlabel('Product Category')
plt.ylabel('Number of Products Sold')
plt.title('10 Produk Terlaris')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Kapan waktu puncak penjualan terjadi?

# %%
allData['order_purchase_timestamp'] = pd.to_datetime(allData['order_purchase_timestamp'])
allData['bulan'] = allData['order_purchase_timestamp'].dt.to_period('M')

penjualan_per_bulan = allData.groupby('bulan')['price'].agg(['sum', 'mean']).reset_index()

print(penjualan_per_bulan)
# Out:
#       bulan         sum        mean
# 0   2016-09      134.97   44.990000
# 1   2016-10    42356.77  125.315888
# 2   2016-12       10.90   10.900000
# 3   2017-01   117757.28  121.901946
# 4   2017-02   237084.38  124.519107
# 5   2017-03   375985.84  123.924140
# 6   2017-04   352163.70  133.445889
# 7   2017-05   520670.93  123.704189
# 8   2017-06   440668.85  120.171489
# 9   2017-07   514643.94  109.522013
# 10  2017-08   578766.95  115.108781
# 11  2017-09   639661.68  129.016071
# 12  2017-10   662259.00  122.007922
# 13  2017-11  1017007.79  116.083528
# 14  2017-12   739398.30  116.900917
# 15  2018-01   944769.33  115.005396
# 16  2018-02   856906.97  110.682895
# 17  2018-03   981484.63  119.011111
# 18  2018-04  1000433.09  124.339186
# 19  2018-05  1008619.60  125.123384
# 20  2018-06   898085.60  123.025425
# 21  2018-07   894355.04  124.700926
# 22  2018-08   866207.88  118.253635

# %%
penjualan_per_bulan['bulan'] = penjualan_per_bulan['bulan'].astype(str) + '-01'
penjualan_per_bulan['bulan'] = pd.to_datetime(penjualan_per_bulan['bulan'])

plt.figure(figsize=(10, 6))
plt.plot(penjualan_per_bulan['bulan'], penjualan_per_bulan['sum'], marker='o', color='b', linestyle='-')
plt.xlabel('Bulan')
plt.ylabel('Total Penjualan')
plt.title('Total Penjualan per Bulan')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Pertanyaan 1: Produk apa saja yang sering dibeli?
#
#     Terlihat bahwa produk yang sering dibeli atau terlaris memiliki setidaknya 4000+ penjualan. produk kategori yang sering dibeli diantaranya cama_mesa_banho, beleza_saude, esporte_lazer, moveis_decoracao, informatica_acessorios, utilidades_domesticas, relogios_presentes, telefonia, ferramentas_jardim dan automotivo.
# - Pertanyaan 2: Kapan waktu puncak penjualan terjadi?
#
#     Terlihat pada grafik, bahwa tren cenderung semakin meningkat dimulai dari akhir tahun 2016 hingga puncaknya pada bulan oktober 2017, kemudian terjadi fluktuasi hingga pertengahan 2018
# - conclusion
#
#     Dapat disimpulkan dari ke-2 pertanyaan tersebut, produk terlaris yang harus dijaga stok atau ketersediaannya ketika terjadi tren peningkatan penjualan atau musiman pada periode tertentu.
